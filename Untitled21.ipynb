# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujapatil069-cell/Assignment-01/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("===================================")
print("      SCIENTIFIC CALCULATOR")
print("===================================")

while True:

    print("\nChoose an Operation")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Modulus")
    print("6. Power")
    print("7. Square Root")
    print("8. Exit")

    choice = input("\nEnter your choice (1-8): ")

    if choice == '8':
        print("Thank you for using Calculator!")
        break

    if choice == '7':
        num = float(input("Enter a number: "))
        sqrt = num ** 0.5
        print("Square Root =", sqrt)
        continue

    if choice in ('1', '2', '3', '4', '5', '6'):

        num1 = float(input("Enter First Number: "))
        num2 = float(input("Enter Second Number: "))

        if choice == '1':
            result = num1 + num2
            print("Result =", result)

        elif choice == '2':
            result = num1 - num2
            print("Result =", result)

        elif choice == '3':
            result = num1 * num2
            print("Result =", result)

        elif choice == '4':
            if num2 == 0:
                print("Error! Division by zero is not allowed.")
            else:
                result = num1 / num2
                print("Result =", result)

        elif choice == '5':
            if num2 == 0:
                print("Error! Modulus by zero is not allowed.")
            else:
                result = num1 % num2
                print("Result =", result)

        elif choice == '6':
            result = num1 ** num2
            print("Result =", result)

    else:
        print("Invalid Choice! Please select between 1 and 8.")

    print("\n-----------------------------------")
# Out:
# ...
#       SCIENTIFIC CALCULATOR
# ...
#
# Choose an Operation
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Exit
#
# Enter your choice (1-8): 4
# Enter First Number: 1
# Enter Second Number: 2
# Result = 0.5
#
# -----------------------------------
#
# Choose an Operation
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Exit
#
# Enter your choice (1-8): 5
# Enter First Number: 1
# Enter Second Number: 2
# Result = 1.0
#
# -----------------------------------
#
# Choose an Operation
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Power
# 7. Square Root
# 8. Exit
#
# Enter your choice (1-8): 5
