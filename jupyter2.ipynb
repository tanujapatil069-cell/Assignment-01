# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujapatil069-cell/Assignment-01/blob/main/jupyter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to calculate length of string

string = input("Enter a string: ")
length = len(string)

print("Length of the string is:", length)
# Out:
# Enter a string: Tanuja
# Length of the string is: 6

# %%
# Program to create new string using first 2 and last 2 characters

string = input("Enter a string: ")

if len(string) < 2:
    print("Empty string")
else:
    new_string = string[:2] + string[-2:]
    print("New string is:", new_string)
# Out:
# Enter a string: Patil
# New string is: Pail

# %%
# Program to concatenate two strings

string1 = input("Enter first string: ")
string2 = input("Enter second string: ")

result = string1 + string2

print("Concatenated string is:", result)
# Out:
# Enter first string: Tanuja
# Enter second string: Patil
# Concatenated string is: Tanuja Patil
