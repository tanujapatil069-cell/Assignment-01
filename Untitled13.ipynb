# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujapatil069-cell/Assignment-01/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=(input("length of string"))
print(a)

a=input("enter first string")
b=input("enter second string")
c= a+b
print(c)

a="Tanuja"
b="patil"
c=a+b
print(c)
# Out:
# length of string5
# 5
# enter first stringTanuja
# enter second stringPatil
# TanujaPatil
# Tanujapatil
